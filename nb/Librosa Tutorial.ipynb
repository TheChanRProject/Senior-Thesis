# %% [markdown]
# # Librosa Tutorial

# %%
# !pip install librosa
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.style as ms
ms.use('seaborn-muted')
# %matplotlib inline
import librosa 
import librosa.display
import IPython.display as ipd
# Out:
# Requirement already satisfied: librosa in /Users/rchatter/miniconda3/lib/python3.6/site-packages (0.6.3)
# Requirement already satisfied: decorator>=3.0.0 in /Users/rchatter/miniconda3/lib/python3.6/site-packages (from librosa) (4.2.1)
# Requirement already satisfied: audioread>=2.0.0 in /Users/rchatter/miniconda3/lib/python3.6/site-packages (from librosa) (2.1.6)
# Requirement already satisfied: resampy>=0.2.0 in /Users/rchatter/miniconda3/lib/python3.6/site-packages (from librosa) (0.2.1)
# Requirement already satisfied: numba>=0.38.0 in /Users/rchatter/miniconda3/lib/python3.6/site-packages (from librosa) (0.43.0)
# Requirement already satisfied: scipy>=1.0.0 in /Users/rchatter/miniconda3/lib/python3.6/site-packages (from librosa) (1.2.1)
# Requirement already satisfied: joblib>=0.12 in /Users/rchatter/miniconda3/lib/python3.6/site-packages (from librosa) (0.13.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /Users/rchatter/miniconda3/lib/python3.6/site-packages (from librosa) (0.20.2)
# Requirement already satisfied: six>=1.3 in /Users/rchatter/miniconda3/lib/python3.6/site-packages (from librosa) (1.12.0)
# Requirement already satisfied: numpy>=1.8.0 in /Users/rchatter/miniconda3/lib/python3.6/site-packages (from librosa) (1.16.2)
# Requirement already satisfied: llvmlite>=0.28.0dev0 in /Users/rchatter/miniconda3/lib/python3.6/site-packages (from numba>=0.38.0->librosa) (0.28.0)
# You are using pip version 19.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
y, sr = librosa.load('/Users/rchatter/Desktop/DS/Python/Senior-Thesis/music_files/samples/pandit-hari-origextract.mp3') 
ipd.Audio(y, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# S = librosa.feature.melspectrogram(y, sr=sr)
# # convert to decibels
# log_S = librosa.power_to_db(S, ref=np.max) 
# plt.figure(figsize=(8,12))
# librosa.display.specshow(S)

# %%
from jupyterthemes import style

# %%
# Chromagram

chromagram = librosa.feature.chroma_cqt(y=y, sr=sr)
plt.figure(figsize=(15,5))
librosa.display.specshow(chromagram, x_axis='time', y_axis='chroma')
